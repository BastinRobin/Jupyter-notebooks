# %% [markdown]
# ## Population Growth between countries
# Lets explore the countries data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
x = [10, 20, 30]
y = [40, 50, 40]
z = [10, 30, 50]
plt.plot(x,y)
plt.plot(x, z)
plt.xlabel('x')
plt.ylabel('y and z')
plt.legend(['y axis', 'z axis'])
plt.show()

# %%
df = pd.read_csv('countries.csv')

# %%
us = df[df['country'] == 'United States']

# %%
china = df[df['country'] == 'China']

# %%
plt.plot(us.year, us.population / 10**6)
plt.plot(china.year, china.population / 10**6)
plt.legend(["US", "China"])
plt.xlabel("Years")
plt.ylabel("Population")
plt.show()

# %%
plt.plot(us.year, us.population / us.population.iloc[0] * 100)
plt.plot(china.year, china.population / china.population.iloc[0] * 100)
plt.legend(["US", "China"])
plt.xlabel("Years")
plt.ylabel("Population growth (First year = 100)")
plt.show()

# %%
# %matplotlib inline

df[df['country']=='Afghanistan'].groupby("year")['population'].mean().plot(kind='bar')

# %%
df[(df['country']=='China')].plot(x='year', y='population')

# %%
a = [[2,6,7,9,9,8],[0,8,6,8,5,8], [6,4,6,2,6,5],[3,5,9,0,3,4],[5,6,7,2,3,4],[5,7,8,6,1,0]]

# %%
a
# Out:
# [[2, 6, 7, 9, 9, 8],
#  [0, 8, 6, 8, 5, 8],
#  [6, 4, 6, 2, 6, 5],
#  [3, 5, 9, 0, 3, 4],
#  [5, 6, 7, 2, 3, 4],
#  [5, 7, 8, 6, 1, 0]]

# %%
for i in range(0,6):
    print a[3][i]
# Out:
# 3
# 5
# 9
# 0
# 3
# 4
